# %% [markdown]
# # Homework
#
# Please select **one** of the two tasks in what follows. Then write you answer in this notebook.
#
# ## Task 1
#
# Recall the infinitesimal generator
#
# $$
# (A \phi)(x) = \nabla_x \phi \cdot a(x) + \frac{1}{2} \mathrm{tr}\big(\Gamma(x) \, \mathrm{H}_x \phi\big), \quad \phi\colon \mathbb{R}^d\to\mathbb{R},
# $$
#
# associated with the SDE
#
# $$
# d X(t) = a(X(t)) dt + b(X(t)) dW(t), \quad X(0) = X_0,\\
# \Gamma(x) := b(x) \, b(x)^\top.
# $$
#
# Now define the SDE coefficients
#
# $$
# a(X(t)) :=
# \begin{bmatrix}
# X_2(t) \\
# X_1(t) \, \bigl(2 - X_1^2(t)\bigr) - X_2(t)
# \end{bmatrix}, \\
# b(X(t)) :=
# \begin{bmatrix}
# 0 \\
# X_1(t).
# \end{bmatrix}
# $$
#
# Approximate the mean $\mathbb{E}[X(t) \mid X(0)]$ and the second moment $\mathbb{E}[X(t) \, X(t)^\top \mid X(0)]$ by using the generator. That is, using the approximation $\mathbb{E}[\phi(X(t)) \mid X(0)] \approx X(0) + (A\phi)(X(0))$. Think what the $\phi$ are to give the mean and second moments?
#
# Implement the approximation as functions of $t$ and $X(0)$, and vectorise the functions over $t$.
#
# ```python
# import jax
# import jax.numpy as jnp
#
# def cond_mean(t, x0):
#     # This function takes (float, vector) as input and returns a vector
#     return ...
#
# def cond_second_moment(t, x0):
#     # This function takes (float, vector) as input and returns a matrix
#     return ...
#
# x0 = jnp.array([-3., 0.])
# ts = jnp.linspace(0.01, 0.2, 100)
#
# means = ? # Vectorise the function cond_mean so that we can evalute cond_mean on ts. Expect means is a (100, 2)-shaped array
# second_moments = ? # Expect second_moments is a (100, 2, 2)-shaped array
# ```
#
# ## Task 2
#
# Implement the Kalman filtering and RTS smoothering in Assignment 1, Exercise 3, in JAX.
